# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from ipywidgets import interact

# %%
@interact(x=10,l=['orange','banane'])
def f(x,l):
    for i in range(x):
        print i," ",l
# Out:
# 0   banane
# 1   banane
# 2   banane
# 3   banane
# 4   banane
# 5   banane
# 6   banane
# 7   banane
# 8   banane
# 9   banane
# 10   banane
# 11   banane
# 12   banane
